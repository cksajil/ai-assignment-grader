# %% [markdown]
# # ANN Assignment
# Student: Sample Student
# Date: 2025-01-15

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load dataset
np.random.seed(42)
data = {
    'age': np.random.randint(20, 60, 100),
    'salary': np.random.normal(50000, 15000, 100),
    'department': np.random.choice(['HR', 'Eng', 'Sales', None], 100),
    'years_exp': np.random.randint(0, 20, 100)
}
df = pd.DataFrame(data)
print(df.shape)

# %%
# Data cleaning — using fillna(0) incorrectly
df2 = df.fillna(0)
print(df2.isnull().sum())

# %%
# Single visualisation — missing second plot
plt.hist(df2['salary'], bins=20, color='steelblue')
plt.show()
